# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.display  import HTML
from IPython.display       import Image

# %% [markdown]
# # Functions

# %%
def personal_settings():
     # plotly settings
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [20, 10]
    plt.rcParams['font.size'] = 24
        
    # notebook settings
    display(HTML('<style>.container{width:90% !important;}</style>'))
    np.set_printoptions(suppress=True)
    pd.set_option('display.float_format', '{:.2f}'.format)

    # seaborn settings
    sns.set(rc={'figure.figsize':(15,10)})
    sns.set_theme(style = 'darkgrid', font_scale = 1.5)

# %%
personal_settings()
# Out:
# <style>.container{width:90% !important;}</style>

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv('kc_house_data.csv')
data
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650    1.00           0     0  ...      7        1180
# 1          7242    2.00           0     0  ...      7        2170
# 2         10000    1.00           0     0  ...      6         770
# 3          5000    1.00           0     0  ...      7        1050
# 4          8080    1.00           0     0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21608      1131    3.00           0     0  ...      8        1530
# 21609      5813    2.00           0     0  ...      8        2310
# 21610      1350    2.00           0     0  ...      7        1020
# 21611      2388    2.00           0     0  ...      8        1600
# 21612      1076    2.00           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# 0                  0      1955             0    98178 47.51 -122.26
# 1                400      1951          1991    98125 47.72 -122.32
# 2                  0      1933             0    98028 47.74 -122.23
# 3                910      1965             0    98136 47.52 -122.39
# 4                  0      1987             0    98074 47.62 -122.05
# ...              ...       ...           ...      ...   ...     ...
# 21608              0      2009             0    98103 47.70 -122.35
# 21609              0      2014             0    98146 47.51 -122.36
# 21610              0      2009             0    98144 47.59 -122.30
# 21611              0      2004             0    98027 47.53 -122.07
# 21612              0      2008             0    98144 47.59 -122.30
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [21613 rows x 21 columns]

# %% [markdown]
# ## Eploratory Analysis

# %%
#check types of variable
data.dtypes
# Out:
# id                 int64
# date              object
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#check dataset size
print('Number of rows: {}'.format(data.shape[0]))
print('Number of columns: {}'.format(data.shape[1]))
# Out:
# Number of rows: 21613
# Number of columns: 21

# %%
#check null values
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#check NaN values
data.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#check duplicates
data[data.duplicated(['id'],keep=False)]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535  20140725T000000   430000         3       1.50         1580
# 94     6021501535  20141223T000000   700000         3       1.50         1580
# 313    4139480200  20140618T000000  1384000         4       3.25         4290
# 314    4139480200  20141209T000000  1400000         4       3.25         4290
# 324    7520000520  20140905T000000   232000         2       1.00         1240
# ...           ...              ...      ...       ...        ...          ...
# 20670  8564860270  20150330T000000   502000         4       2.50         2680
# 20779  6300000226  20140626T000000   240000         4       1.00         1200
# 20780  6300000226  20150504T000000   380000         4       1.00         1200
# 21580  7853420110  20141003T000000   594866         3       3.00         2780
# 21581  7853420110  20150504T000000   625000         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 93         5000    1.00           0     0  ...      8        1290
# 94         5000    1.00           0     0  ...      8        1290
# 313       12103    1.00           0     3  ...     11        2690
# 314       12103    1.00           0     3  ...     11        2690
# 324       12092    1.00           0     0  ...      6         960
# ...         ...     ...         ...   ...  ...    ...         ...
# 20670      5539    2.00           0     0  ...      8        2680
# 20779      2171    1.50           0     0  ...      7        1200
# 20780      2171    1.50           0     0  ...      7        1200
# 21580      6000    2.00           0     0  ...      9        2780
# 21581      6000    2.00           0     0  ...      9        2780
#
#        sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# 93               290      1939             0    98117 47.69 -122.39
# 94               290      1939             0    98117 47.69 -122.39
# 313             1600      1997             0    98006 47.55 -122.10
# 314             1600      1997             0    98006 47.55 -122.10
# 324              280      1922          1984    98146 47.50 -122.35
# ...              ...       ...           ...      ...   ...     ...
# 20670              0      2013             0    98045 47.48 -121.73
# 20779              0      1933             0    98133 47.71 -122.34
# 20780              0      1933             0    98133 47.71 -122.34
# 21580              0      2013             0    98065 47.52 -121.89
# 21581              0      2013             0    98065 47.52 -121.89
#
#        sqft_living15  sqft_lot15
# 93              1570        4500
# 94              1570        4500
# 313             3860       11244
# 314             3860       11244
# 324             1820        7460
# ...              ...         ...
# 20670           2680        5992
# 20779           1130        1598
# 20780           1130        1598
# 21580           2850        6000
# 21581           2850        6000
#
# [353 rows x 21 columns]

# %%
#separate numerical attributes
df_attributes = data.select_dtypes(include = ['int64', 'float64'])
#check numerical attributes statistical behaviour
avg = pd.DataFrame(df_attributes.apply(np.mean))
median = pd.DataFrame(df_attributes.apply(np.median))
max_= pd.DataFrame(df_attributes.apply(np.max))
min_= pd.DataFrame(df_attributes.apply(np.min))
std = pd.DataFrame(df_attributes.apply(np.std))

df_stats = pd.concat([avg, median, max_, min_, std], axis = 1).reset_index()
df_stats.columns = ['attributes','mean', 'median', 'max_value', 'min_value', 'std']
df_stats
# Out:
#        attributes          mean        median     max_value  min_value  \
# 0              id 4580301520.86 3904930410.00 9900000190.00 1000102.00
# 1           price     540088.14     450000.00    7700000.00   75000.00
# 2        bedrooms          3.37          3.00         33.00       0.00
# 3       bathrooms          2.11          2.25          8.00       0.00
# 4     sqft_living       2079.90       1910.00      13540.00     290.00
# 5        sqft_lot      15106.97       7618.00    1651359.00     520.00
# 6          floors          1.49          1.50          3.50       1.00
# 7      waterfront          0.01          0.00          1.00       0.00
# 8            view          0.23          0.00          4.00       0.00
# 9       condition          3.41          3.00          5.00       1.00
# 10          grade          7.66          7.00         13.00       1.00
# 11     sqft_above       1788.39       1560.00       9410.00     290.00
# 12  sqft_basement        291.51          0.00       4820.00       0.00
# 13       yr_built       1971.01       1975.00       2015.00    1900.00
# 14   yr_renovated         84.40          0.00       2015.00       0.00
# 15        zipcode      98077.94      98065.00      98199.00   98001.00
# 16            lat         47.56         47.57         47.78      47.16
# 17           long       -122.21       -122.23       -121.31    -122.52
# 18  sqft_living15       1986.55       1840.00       6210.00     399.00
# 19     sqft_lot15      12768.46       7620.00     871200.00     651.00
#
#              std
# 0  2876499023.43
# 1      367118.70
# 2           0.93
# 3           0.77
# 4         918.42
# 5       41419.55
# 6           0.54
# 7           0.09
# 8           0.77
# 9           0.65
# 10          1.18
# 11        828.07
# 12        442.56
# 13         29.37
# 14        401.67
# 15         53.50
# 16          0.14
# 17          0.14
# 18        685.38
# 19      27303.55

# %%
#From df_stats, noticed large diffence (possible error)
print(data.groupby(['bedrooms']).size())
# Out:
# bedrooms
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# dtype: int64

# %%
#check mean living area per number of bedrooms
print(data[['sqft_living', 'bedrooms']].groupby(['bedrooms']).mean().reset_index().sort_values(by = 'sqft_living'))
#houses listed with 33 and 11 rooms considered to be typing error. houses with 0 bedrooms considered to be not attractive. Drop those.
# Out:
#     bedrooms  sqft_living
# 1          1       884.61
# 2          2      1239.75
# 12        33      1620.00
# 0          0      1707.85
# 3          3      1805.84
# 4          4      2554.65
# 11        11      3000.00
# 5          5      3047.55
# 6          6      3284.34
# 10        10      3706.67
# 9          9      3775.00
# 8          8      3800.00
# 7          7      3974.21

# %% [markdown]
# # Transform Data

# %%
#trasform column 'date' to date format
data['date'] = pd.to_datetime(data['date'])
data.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                     int64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
#Remove duplicates based on 'id'
data.drop_duplicates(subset="id", keep='last', inplace=True)
print('Number of rows after remove duplicates: {}'.format(data.shape[0]))
# Out:
# Number of rows after remove duplicates: 21436

# %%
#Remove outliers
data = data[(data['bedrooms'] != 0) & (data['bedrooms'] != 11) & (data['bedrooms'] != 33)]
print(data.groupby(['bedrooms']).size())
# Out:
# bedrooms
# 1      194
# 2     2736
# 3     9731
# 4     6849
# 5     1586
# 6      265
# 7       38
# 8       13
# 9        6
# 10       3
# dtype: int64

# %%
#check data after data cleaning
df_attributes = data.select_dtypes(include = ['int64', 'float64'])
#check numerical attributes statistical behaviour
avg = pd.DataFrame(df_attributes.apply(np.mean))
median = pd.DataFrame(df_attributes.apply(np.median))
max_= pd.DataFrame(df_attributes.apply(np.max))
min_= pd.DataFrame(df_attributes.apply(np.min))
std = pd.DataFrame(df_attributes.apply(np.std))

df_stats = pd.concat([avg, median, max_, min_, std], axis = 1).reset_index()
df_stats.columns = ['attributes','mean', 'median', 'max_value', 'min_value', 'std']
df_stats
# Out:
#        attributes          mean        median     max_value  min_value  \
# 0              id 4580966503.68 3904921250.00 9900000190.00 1000102.00
# 1           price     541726.58     450500.00    7700000.00   75000.00
# 2        bedrooms          3.37          3.00         10.00       1.00
# 3       bathrooms          2.12          2.25          8.00       0.00
# 4     sqft_living       2082.91       1920.00      13540.00     370.00
# 5        sqft_lot      15131.07       7615.00    1651359.00     520.00
# 6          floors          1.50          1.50          3.50       1.00
# 7      waterfront          0.01          0.00          1.00       0.00
# 8            view          0.24          0.00          4.00       0.00
# 9       condition          3.41          3.00          5.00       1.00
# 10          grade          7.66          7.00         13.00       3.00
# 11     sqft_above       1791.02       1560.00       9410.00     370.00
# 12  sqft_basement        291.89          0.00       4820.00       0.00
# 13       yr_built       1971.09       1975.00       2015.00    1900.00
# 14   yr_renovated         84.70          0.00       2015.00       0.00
# 15        zipcode      98077.87      98065.00      98199.00   98001.00
# 16            lat         47.56         47.57         47.78      47.16
# 17           long       -122.21       -122.23       -121.31    -122.52
# 18  sqft_living15       1988.34       1840.00       6210.00     399.00
# 19     sqft_lot15      12778.63       7620.00     871200.00     651.00
#
#              std
# 0  2876701014.41
# 1      367321.78
# 2           0.90
# 3           0.77
# 4         918.89
# 5       41529.29
# 6           0.54
# 7           0.09
# 8           0.77
# 9           0.65
# 10          1.17
# 11        828.74
# 12        442.86
# 13         29.38
# 14        402.34
# 15         53.48
# 16          0.14
# 17          0.14
# 18        685.54
# 19      27345.13

# %%
sns.set(rc={'figure.figsize':(30,20)})
df_attributes.hist(bins=25);
personal_settings()
# Out:
# <style>.container{width:90% !important;}</style>

# %% [markdown]
# # Adding new features

# %%
#Adding column with median_price per zipcode
decision_df = data[['id', 'zipcode', 'date', 'condition', 'grade', 'price']].copy()
zc_median_price = decision_df[['price', 'zipcode']].groupby('zipcode').median().reset_index()
decision_df = pd.merge(decision_df, zc_median_price, on = 'zipcode', how = 'inner').rename(columns = {'price_x':'buying_price', 'price_y': 'median_price'})
decision_df['buying_price'] = decision_df['buying_price'].astype('float64')
decision_df
# Out:
#                id  zipcode       date  condition  grade  buying_price  \
# 0      7129300520    98178 2014-10-13          3      7     221900.00
# 1      4060000240    98178 2014-06-23          4      6     205425.00
# 2      4058801670    98178 2014-07-17          3      8     445000.00
# 3      2976800796    98178 2014-09-25          3      7     236000.00
# 4      6874200960    98178 2015-02-27          3      6     170000.00
# ...           ...      ...        ...        ...    ...           ...
# 21416  2525049086    98039 2014-10-03          4     11    2720000.00
# 21417  2525049113    98039 2014-07-25          4     10    1950000.00
# 21418  3262300485    98039 2015-04-21          3     11    2250000.00
# 21419  6447300365    98039 2014-11-13          3     11    2900000.00
# 21420  3262300818    98039 2015-02-27          3     11    1865000.00
#
#        median_price
# 0         279500.00
# 1         279500.00
# 2         279500.00
# 3         279500.00
# 4         279500.00
# ...             ...
# 21416    1905000.00
# 21417    1905000.00
# 21418    1905000.00
# 21419    1905000.00
# 21420    1905000.00
#
# [21421 rows x 7 columns]

# %%
#Adding column with buy/no_buy recommendation
decision_df['recommendation'] = decision_df[['condition', 'buying_price', 'median_price']].apply(lambda x: 'buy' if (x['condition'] >= 3) & (x['buying_price'] < x['median_price']) else 'no_buy', axis = 1)
buy = decision_df[decision_df['recommendation'] == 'buy'].shape[0]
no_buy = decision_df.shape[0]-buy
print('No total temos {} imoveis para comprar e {} para nao comprar\n'.format(buy, no_buy))
decision_df
# Out:
# No total temos 10500 imoveis para comprar e 10921 para nao comprar
#                id  zipcode       date  condition  grade  buying_price  \
# 0      7129300520    98178 2014-10-13          3      7     221900.00
# 1      4060000240    98178 2014-06-23          4      6     205425.00
# 2      4058801670    98178 2014-07-17          3      8     445000.00
# 3      2976800796    98178 2014-09-25          3      7     236000.00
# 4      6874200960    98178 2015-02-27          3      6     170000.00
# ...           ...      ...        ...        ...    ...           ...
# 21416  2525049086    98039 2014-10-03          4     11    2720000.00
# 21417  2525049113    98039 2014-07-25          4     10    1950000.00
# 21418  3262300485    98039 2015-04-21          3     11    2250000.00
# 21419  6447300365    98039 2014-11-13          3     11    2900000.00
# 21420  3262300818    98039 2015-02-27          3     11    1865000.00
#
#        median_price recommendation
# 0         279500.00            buy
# 1         279500.00            buy
# 2         279500.00         no_buy
# 3         279500.00            buy
# 4         279500.00            buy
# ...             ...            ...
# 21416    1905000.00         no_buy
# 21417    1905000.00         no_buy
# 21418    1905000.00         no_buy
# 21419    1905000.00         no_buy
# 21420    1905000.00            buy
#
# [21421 rows x 8 columns]

# %%
#Creating column season
season_df = decision_df[decision_df['recommendation'] == 'buy'].copy()
season_df['month'] = season_df['date'].dt.month
season_df['season'] = season_df['month'].apply(lambda x: 'spring' if (x >= 3) & (x < 6) else
                                                         'summer' if (x >= 6) & (x < 9) else
                                                         'fall'   if (x >= 9) & (x < 12) else
                                                         'winter')
season_df
# Out:
#                id  zipcode       date  condition  grade  buying_price  \
# 0      7129300520    98178 2014-10-13          3      7     221900.00
# 1      4060000240    98178 2014-06-23          4      6     205425.00
# 3      2976800796    98178 2014-09-25          3      7     236000.00
# 4      6874200960    98178 2015-02-27          3      6     170000.00
# 5      4268200055    98178 2015-05-01          3      7     245000.00
# ...           ...      ...        ...        ...    ...           ...
# 21408  3025300225    98039 2014-10-31          4      9    1450000.00
# 21409  2470200020    98039 2014-05-14          4     10    1880000.00
# 21411  3625049079    98039 2014-08-01          3      7    1350000.00
# 21413  5427100150    98039 2014-06-26          3      9    1410000.00
# 21420  3262300818    98039 2015-02-27          3     11    1865000.00
#
#        median_price recommendation  month  season
# 0         279500.00            buy     10    fall
# 1         279500.00            buy      6  summer
# 3         279500.00            buy      9    fall
# 4         279500.00            buy      2  winter
# 5         279500.00            buy      5  spring
# ...             ...            ...    ...     ...
# 21408    1905000.00            buy     10    fall
# 21409    1905000.00            buy      5  spring
# 21411    1905000.00            buy      8  summer
# 21413    1905000.00            buy      6  summer
# 21420    1905000.00            buy      2  winter
#
# [10500 rows x 10 columns]

# %%
median_season_df = season_df[['buying_price', 'zipcode', 'season']].groupby(['season','zipcode']).median().sort_values(by = 'zipcode').reset_index()
median_season_df
# Out:
#      season  zipcode  buying_price
# 0      fall    98001     217500.00
# 1    summer    98001     213300.00
# 2    spring    98001     212750.00
# 3    winter    98001     228250.00
# 4    winter    98002     189000.00
# ..      ...      ...           ...
# 275    fall    98198     219000.00
# 276  spring    98199     543115.00
# 277    fall    98199     511200.00
# 278  summer    98199     520000.00
# 279  winter    98199     565000.00
#
# [280 rows x 3 columns]

# %%
#Create columns for median price of each season
median_season_df = median_season_df.pivot(index = 'zipcode', columns = 'season', values = 'buying_price').reset_index()
median_season_df
# Out:
# season  zipcode      fall    spring    summer    winter
# 0         98001 217500.00 212750.00 213300.00 228250.00
# 1         98002 195250.00 206000.00 207975.00 189000.00
# 2         98003 223500.00 242000.00 227000.00 228245.00
# 3         98004 823000.00 865000.00 815000.00 825000.00
# 4         98005 580000.00 633725.00 666250.00 635000.00
# ..          ...       ...       ...       ...       ...
# 65        98177 432450.00 460000.00 420000.00 412250.00
# 66        98178 216500.00 229250.00 227000.00 222900.00
# 67        98188 240000.00 225000.00 231500.00 220000.00
# 68        98198 219000.00 210000.00 223000.00 220000.00
# 69        98199 511200.00 543115.00 520000.00 565000.00
#
# [70 rows x 5 columns]

# %%
median_season_df.columns = ['zipcode', 'fall_median', 'spring_median', 'summer_median', 'winter_median']
median_season_df
# Out:
#     zipcode  fall_median  spring_median  summer_median  winter_median
# 0     98001    217500.00      212750.00      213300.00      228250.00
# 1     98002    195250.00      206000.00      207975.00      189000.00
# 2     98003    223500.00      242000.00      227000.00      228245.00
# 3     98004    823000.00      865000.00      815000.00      825000.00
# 4     98005    580000.00      633725.00      666250.00      635000.00
# ..      ...          ...            ...            ...            ...
# 65    98177    432450.00      460000.00      420000.00      412250.00
# 66    98178    216500.00      229250.00      227000.00      222900.00
# 67    98188    240000.00      225000.00      231500.00      220000.00
# 68    98198    219000.00      210000.00      223000.00      220000.00
# 69    98199    511200.00      543115.00      520000.00      565000.00
#
# [70 rows x 5 columns]

# %%
#merging and filtering relevant data to suggest price for sale
dataset = pd.merge(season_df, median_season_df, on = 'zipcode', how = 'inner')
dataset = dataset[['id', 'date', 'zipcode', 'buying_price', 'median_price', 'season', 'fall_median', 'spring_median', 'summer_median', 'winter_median']].copy()
dataset
# Out:
#                id       date  zipcode  buying_price  median_price  season  \
# 0      7129300520 2014-10-13    98178     221900.00     279500.00    fall
# 1      4060000240 2014-06-23    98178     205425.00     279500.00  summer
# 2      2976800796 2014-09-25    98178     236000.00     279500.00    fall
# 3      6874200960 2015-02-27    98178     170000.00     279500.00  winter
# 4      4268200055 2015-05-01    98178     245000.00     279500.00  spring
# ...           ...        ...      ...           ...           ...     ...
# 10495  3025300225 2014-10-31    98039    1450000.00    1905000.00    fall
# 10496  2470200020 2014-05-14    98039    1880000.00    1905000.00  spring
# 10497  3625049079 2014-08-01    98039    1350000.00    1905000.00  summer
# 10498  5427100150 2014-06-26    98039    1410000.00    1905000.00  summer
# 10499  3262300818 2015-02-27    98039    1865000.00    1905000.00  winter
#
#        fall_median  spring_median  summer_median  winter_median
# 0        216500.00      229250.00      227000.00      222900.00
# 1        216500.00      229250.00      227000.00      222900.00
# 2        216500.00      229250.00      227000.00      222900.00
# 3        216500.00      229250.00      227000.00      222900.00
# 4        216500.00      229250.00      227000.00      222900.00
# ...            ...            ...            ...            ...
# 10495   1450000.00     1620000.00     1335000.00     1402500.00
# 10496   1450000.00     1620000.00     1335000.00     1402500.00
# 10497   1450000.00     1620000.00     1335000.00     1402500.00
# 10498   1450000.00     1620000.00     1335000.00     1402500.00
# 10499   1450000.00     1620000.00     1335000.00     1402500.00
#
# [10500 rows x 10 columns]

# %%
# add column with suggest sale price
dataset['fall_selling_price'] = dataset[['buying_price', 'fall_median']].apply(lambda x: x['buying_price']*1.3 if x['buying_price'] <= x['fall_median'] else
                                                                                         x['buying_price']*1.1, axis=1)
dataset['spring_selling_price'] = dataset[['buying_price', 'spring_median']].apply(lambda x: x['buying_price']*1.3 if x['buying_price'] <= x['spring_median'] else
                                                                                         x['buying_price']*1.1, axis=1)
dataset['summer_selling_price'] = dataset[['buying_price', 'summer_median']].apply(lambda x: x['buying_price']*1.3 if x['buying_price'] <= x['summer_median'] else
                                                                                         x['buying_price']*1.1, axis=1)
dataset['winter_selling_price'] = dataset[['buying_price', 'winter_median']].apply(lambda x: x['buying_price']*1.3 if x['buying_price'] <= x['winter_median'] else
                                                                                         x['buying_price']*1.1, axis=1)
dataset
# Out:
#                id       date  zipcode  buying_price  median_price  season  \
# 0      7129300520 2014-10-13    98178     221900.00     279500.00    fall
# 1      4060000240 2014-06-23    98178     205425.00     279500.00  summer
# 2      2976800796 2014-09-25    98178     236000.00     279500.00    fall
# 3      6874200960 2015-02-27    98178     170000.00     279500.00  winter
# 4      4268200055 2015-05-01    98178     245000.00     279500.00  spring
# ...           ...        ...      ...           ...           ...     ...
# 10495  3025300225 2014-10-31    98039    1450000.00    1905000.00    fall
# 10496  2470200020 2014-05-14    98039    1880000.00    1905000.00  spring
# 10497  3625049079 2014-08-01    98039    1350000.00    1905000.00  summer
# 10498  5427100150 2014-06-26    98039    1410000.00    1905000.00  summer
# 10499  3262300818 2015-02-27    98039    1865000.00    1905000.00  winter
#
#        fall_median  spring_median  summer_median  winter_median  \
# 0        216500.00      229250.00      227000.00      222900.00
# 1        216500.00      229250.00      227000.00      222900.00
# 2        216500.00      229250.00      227000.00      222900.00
# 3        216500.00      229250.00      227000.00      222900.00
# 4        216500.00      229250.00      227000.00      222900.00
# ...            ...            ...            ...            ...
# 10495   1450000.00     1620000.00     1335000.00     1402500.00
# 10496   1450000.00     1620000.00     1335000.00     1402500.00
# 10497   1450000.00     1620000.00     1335000.00     1402500.00
# 10498   1450000.00     1620000.00     1335000.00     1402500.00
# 10499   1450000.00     1620000.00     1335000.00     1402500.00
#
#        fall_selling_price  spring_selling_price  summer_selling_price  \
# 0               244090.00             288470.00             288470.00
# 1               267052.50             267052.50             267052.50
# 2               259600.00             259600.00             259600.00
# 3               221000.00             221000.00             221000.00
# 4               269500.00             269500.00             269500.00
# ...                   ...                   ...                   ...
# 10495          1885000.00            1885000.00            1595000.00
# 10496          2068000.00            2068000.00            2068000.00
# 10497          1755000.00            1755000.00            1485000.00
# 10498          1833000.00            1833000.00            1551000.00
# 10499          2051500.00            2051500.00            2051500.00
#
#        winter_selling_price
# 0                 288470.00
# 1                 267052.50
# 2                 259600.00
# 3                 221000.00
# 4                 269500.00
# ...                     ...
# 10495            1595000.00
# 10496            2068000.00
# 10497            1755000.00
# 10498            1551000.00
# 10499            2051500.00
#
# [10500 rows x 14 columns]

# %%
#Add columns with min and max selling_price
dataset['min_selling_price'] = dataset[['fall_selling_price', 'spring_selling_price', 'summer_selling_price', 'winter_selling_price']].min(axis = 1)
dataset['max_selling_price'] = dataset[['fall_selling_price', 'spring_selling_price', 'summer_selling_price', 'winter_selling_price']].max(axis = 1)
dataset
# Out:
#                id       date  zipcode  buying_price  median_price  season  \
# 0      7129300520 2014-10-13    98178     221900.00     279500.00    fall
# 1      4060000240 2014-06-23    98178     205425.00     279500.00  summer
# 2      2976800796 2014-09-25    98178     236000.00     279500.00    fall
# 3      6874200960 2015-02-27    98178     170000.00     279500.00  winter
# 4      4268200055 2015-05-01    98178     245000.00     279500.00  spring
# ...           ...        ...      ...           ...           ...     ...
# 10495  3025300225 2014-10-31    98039    1450000.00    1905000.00    fall
# 10496  2470200020 2014-05-14    98039    1880000.00    1905000.00  spring
# 10497  3625049079 2014-08-01    98039    1350000.00    1905000.00  summer
# 10498  5427100150 2014-06-26    98039    1410000.00    1905000.00  summer
# 10499  3262300818 2015-02-27    98039    1865000.00    1905000.00  winter
#
#        fall_median  spring_median  summer_median  winter_median  \
# 0        216500.00      229250.00      227000.00      222900.00
# 1        216500.00      229250.00      227000.00      222900.00
# 2        216500.00      229250.00      227000.00      222900.00
# 3        216500.00      229250.00      227000.00      222900.00
# 4        216500.00      229250.00      227000.00      222900.00
# ...            ...            ...            ...            ...
# 10495   1450000.00     1620000.00     1335000.00     1402500.00
# 10496   1450000.00     1620000.00     1335000.00     1402500.00
# 10497   1450000.00     1620000.00     1335000.00     1402500.00
# 10498   1450000.00     1620000.00     1335000.00     1402500.00
# 10499   1450000.00     1620000.00     1335000.00     1402500.00
#
#        fall_selling_price  spring_selling_price  summer_selling_price  \
# 0               244090.00             288470.00             288470.00
# 1               267052.50             267052.50             267052.50
# 2               259600.00             259600.00             259600.00
# 3               221000.00             221000.00             221000.00
# 4               269500.00             269500.00             269500.00
# ...                   ...                   ...                   ...
# 10495          1885000.00            1885000.00            1595000.00
# 10496          2068000.00            2068000.00            2068000.00
# 10497          1755000.00            1755000.00            1485000.00
# 10498          1833000.00            1833000.00            1551000.00
# 10499          2051500.00            2051500.00            2051500.00
#
#        winter_selling_price  min_selling_price  max_selling_price
# 0                 288470.00          244090.00          288470.00
# 1                 267052.50          267052.50          267052.50
# 2                 259600.00          259600.00          259600.00
# 3                 221000.00          221000.00          221000.00
# 4                 269500.00          269500.00          269500.00
# ...                     ...                ...                ...
# 10495            1595000.00         1595000.00         1885000.00
# 10496            2068000.00         2068000.00         2068000.00
# 10497            1755000.00         1485000.00         1755000.00
# 10498            1551000.00         1551000.00         1833000.00
# 10499            2051500.00         2051500.00         2051500.00
#
# [10500 rows x 16 columns]

# %%
#Creating column with recommended season for selling (make sure to cover all possibilities)
dataset['sell_at'] = dataset[['fall_selling_price', 'spring_selling_price', 'summer_selling_price', 'winter_selling_price', 'max_selling_price']].apply(lambda x: 
                                                                                                                                                                'fall' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) else
                                                                                                                                                                'summer' if (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) else
                                                                                                                                                                'spring' if (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) else
                                                                                                                                                                'winter' if (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) else
                                                                                                                                                                'fall_or_summer' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) else
                                                                                                                                                                'fall_or_spring' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) else
                                                                                                                                                                'fall_or_winter' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) else
                                                                                                                                                                'summer_or_spring' if (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) else
                                                                                                                                                                'summer_or_winter' if (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) else
                                                                                                                                                                'spring_or_winter' if (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) else
                                                                                                                                                                'fall_or_summer_or_spring' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] != x['winter_selling_price']) else
                                                                                                                                                                'fall_or_summer_or_winter' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['spring_selling_price']) else
                                                                                                                                                                'fall_or_spring_or_winter' if (x['max_selling_price'] == x['fall_selling_price']) & (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['summer_selling_price']) else
                                                                                                                                                                'summer_or_spring_or_winter' if (x['max_selling_price'] == x['summer_selling_price']) & (x['max_selling_price'] == x['spring_selling_price']) & (x['max_selling_price'] == x['winter_selling_price']) & (x['max_selling_price'] != x['fall_selling_price']) else
                                                                                                                                                                'any_season', 
                                                                                                                                                                 axis = 1)
dataset
# Out:
#                id       date  zipcode  buying_price  median_price  season  \
# 0      7129300520 2014-10-13    98178     221900.00     279500.00    fall
# 1      4060000240 2014-06-23    98178     205425.00     279500.00  summer
# 2      2976800796 2014-09-25    98178     236000.00     279500.00    fall
# 3      6874200960 2015-02-27    98178     170000.00     279500.00  winter
# 4      4268200055 2015-05-01    98178     245000.00     279500.00  spring
# ...           ...        ...      ...           ...           ...     ...
# 10495  3025300225 2014-10-31    98039    1450000.00    1905000.00    fall
# 10496  2470200020 2014-05-14    98039    1880000.00    1905000.00  spring
# 10497  3625049079 2014-08-01    98039    1350000.00    1905000.00  summer
# 10498  5427100150 2014-06-26    98039    1410000.00    1905000.00  summer
# 10499  3262300818 2015-02-27    98039    1865000.00    1905000.00  winter
#
#        fall_median  spring_median  summer_median  winter_median  \
# 0        216500.00      229250.00      227000.00      222900.00
# 1        216500.00      229250.00      227000.00      222900.00
# 2        216500.00      229250.00      227000.00      222900.00
# 3        216500.00      229250.00      227000.00      222900.00
# 4        216500.00      229250.00      227000.00      222900.00
# ...            ...            ...            ...            ...
# 10495   1450000.00     1620000.00     1335000.00     1402500.00
# 10496   1450000.00     1620000.00     1335000.00     1402500.00
# 10497   1450000.00     1620000.00     1335000.00     1402500.00
# 10498   1450000.00     1620000.00     1335000.00     1402500.00
# 10499   1450000.00     1620000.00     1335000.00     1402500.00
#
#        fall_selling_price  spring_selling_price  summer_selling_price  \
# 0               244090.00             288470.00             288470.00
# 1               267052.50             267052.50             267052.50
# 2               259600.00             259600.00             259600.00
# 3               221000.00             221000.00             221000.00
# 4               269500.00             269500.00             269500.00
# ...                   ...                   ...                   ...
# 10495          1885000.00            1885000.00            1595000.00
# 10496          2068000.00            2068000.00            2068000.00
# 10497          1755000.00            1755000.00            1485000.00
# 10498          1833000.00            1833000.00            1551000.00
# 10499          2051500.00            2051500.00            2051500.00
#
#        winter_selling_price  min_selling_price  max_selling_price  \
# 0                 288470.00          244090.00          288470.00
# 1                 267052.50          267052.50          267052.50
# 2                 259600.00          259600.00          259600.00
# 3                 221000.00          221000.00          221000.00
# 4                 269500.00          269500.00          269500.00
# ...                     ...                ...                ...
# 10495            1595000.00         1595000.00         1885000.00
# 10496            2068000.00         2068000.00         2068000.00
# 10497            1755000.00         1485000.00         1755000.00
# 10498            1551000.00         1551000.00         1833000.00
# 10499            2051500.00         2051500.00         2051500.00
#
#                           sell_at
# 0      summer_or_spring_or_winter
# 1                      any_season
# 2                      any_season
# 3                      any_season
# 4                      any_season
# ...                           ...
# 10495              fall_or_spring
# 10496                  any_season
# 10497    fall_or_spring_or_winter
# 10498              fall_or_spring
# 10499                  any_season
#
# [10500 rows x 17 columns]

# %%
# add column with expected profit
dataset['max_profit'] = dataset[['buying_price', 'max_selling_price']].apply(lambda x: x['max_selling_price'] - x['buying_price'], axis=1)
dataset['min_profit'] = dataset[['buying_price', 'min_selling_price']].apply(lambda x: x['min_selling_price'] - x['buying_price'], axis=1)
dataset
# Out:
#                id       date  zipcode  buying_price  median_price  season  \
# 0      7129300520 2014-10-13    98178     221900.00     279500.00    fall
# 1      4060000240 2014-06-23    98178     205425.00     279500.00  summer
# 2      2976800796 2014-09-25    98178     236000.00     279500.00    fall
# 3      6874200960 2015-02-27    98178     170000.00     279500.00  winter
# 4      4268200055 2015-05-01    98178     245000.00     279500.00  spring
# ...           ...        ...      ...           ...           ...     ...
# 10495  3025300225 2014-10-31    98039    1450000.00    1905000.00    fall
# 10496  2470200020 2014-05-14    98039    1880000.00    1905000.00  spring
# 10497  3625049079 2014-08-01    98039    1350000.00    1905000.00  summer
# 10498  5427100150 2014-06-26    98039    1410000.00    1905000.00  summer
# 10499  3262300818 2015-02-27    98039    1865000.00    1905000.00  winter
#
#        fall_median  spring_median  summer_median  winter_median  \
# 0        216500.00      229250.00      227000.00      222900.00
# 1        216500.00      229250.00      227000.00      222900.00
# 2        216500.00      229250.00      227000.00      222900.00
# 3        216500.00      229250.00      227000.00      222900.00
# 4        216500.00      229250.00      227000.00      222900.00
# ...            ...            ...            ...            ...
# 10495   1450000.00     1620000.00     1335000.00     1402500.00
# 10496   1450000.00     1620000.00     1335000.00     1402500.00
# 10497   1450000.00     1620000.00     1335000.00     1402500.00
# 10498   1450000.00     1620000.00     1335000.00     1402500.00
# 10499   1450000.00     1620000.00     1335000.00     1402500.00
#
#        fall_selling_price  spring_selling_price  summer_selling_price  \
# 0               244090.00             288470.00             288470.00
# 1               267052.50             267052.50             267052.50
# 2               259600.00             259600.00             259600.00
# 3               221000.00             221000.00             221000.00
# 4               269500.00             269500.00             269500.00
# ...                   ...                   ...                   ...
# 10495          1885000.00            1885000.00            1595000.00
# 10496          2068000.00            2068000.00            2068000.00
# 10497          1755000.00            1755000.00            1485000.00
# 10498          1833000.00            1833000.00            1551000.00
# 10499          2051500.00            2051500.00            2051500.00
#
#        winter_selling_price  min_selling_price  max_selling_price  \
# 0                 288470.00          244090.00          288470.00
# 1                 267052.50          267052.50          267052.50
# 2                 259600.00          259600.00          259600.00
# 3                 221000.00          221000.00          221000.00
# 4                 269500.00          269500.00          269500.00
# ...                     ...                ...                ...
# 10495            1595000.00         1595000.00         1885000.00
# 10496            2068000.00         2068000.00         2068000.00
# 10497            1755000.00         1485000.00         1755000.00
# 10498            1551000.00         1551000.00         1833000.00
# 10499            2051500.00         2051500.00         2051500.00
#
#                           sell_at  max_profit  min_profit
# 0      summer_or_spring_or_winter    66570.00    22190.00
# 1                      any_season    61627.50    61627.50
# 2                      any_season    23600.00    23600.00
# 3                      any_season    51000.00    51000.00
# 4                      any_season    24500.00    24500.00
# ...                           ...         ...         ...
# 10495              fall_or_spring   435000.00   145000.00
# 10496                  any_season   188000.00   188000.00
# 10497    fall_or_spring_or_winter   405000.00   135000.00
# 10498              fall_or_spring   423000.00   141000.00
# 10499                  any_season   186500.00   186500.00
#
# [10500 rows x 19 columns]

# %%
#summarizing data
summ_dataset = dataset[['id','zipcode', 'buying_price', 'median_price', 'min_selling_price', 'max_selling_price', 'min_profit', 'max_profit', 'sell_at']].copy()
summ_dataset
# Out:
#                id  zipcode  buying_price  median_price  min_selling_price  \
# 0      7129300520    98178     221900.00     279500.00          244090.00
# 1      4060000240    98178     205425.00     279500.00          267052.50
# 2      2976800796    98178     236000.00     279500.00          259600.00
# 3      6874200960    98178     170000.00     279500.00          221000.00
# 4      4268200055    98178     245000.00     279500.00          269500.00
# ...           ...      ...           ...           ...                ...
# 10495  3025300225    98039    1450000.00    1905000.00         1595000.00
# 10496  2470200020    98039    1880000.00    1905000.00         2068000.00
# 10497  3625049079    98039    1350000.00    1905000.00         1485000.00
# 10498  5427100150    98039    1410000.00    1905000.00         1551000.00
# 10499  3262300818    98039    1865000.00    1905000.00         2051500.00
#
#        max_selling_price  min_profit  max_profit                     sell_at
# 0              288470.00    22190.00    66570.00  summer_or_spring_or_winter
# 1              267052.50    61627.50    61627.50                  any_season
# 2              259600.00    23600.00    23600.00                  any_season
# 3              221000.00    51000.00    51000.00                  any_season
# 4              269500.00    24500.00    24500.00                  any_season
# ...                  ...         ...         ...                         ...
# 10495         1885000.00   145000.00   435000.00              fall_or_spring
# 10496         2068000.00   188000.00   188000.00                  any_season
# 10497         1755000.00   135000.00   405000.00    fall_or_spring_or_winter
# 10498         1833000.00   141000.00   423000.00              fall_or_spring
# 10499         2051500.00   186500.00   186500.00                  any_season
#
# [10500 rows x 9 columns]

# %%
max_profit = summ_dataset['max_profit'].sum()
min_profit = summ_dataset['min_profit'].sum()
print('By following the buying recommendations, minimum profit expected is ${}. \n The maximun profit expected is ${}'.format(round(min_profit,2), round(max_profit,2)))
# Out:
# By following the buying recommendations, minimum profit expected is $694433672.2.
#  The maximun profit expected is $839540926.8

# %% [markdown]
# # Hypotesis

# %% [markdown]
# H1: Houses with water view are 30% more expensive, in average.

# %%
df = data[['price', 'waterfront']].groupby('waterfront').mean().reset_index()
print(df)
H1 = ((df.iloc[1,1]-df.iloc[0,1])/df.iloc[0,1])*100
print('Houses with water view are {}% more expensive in average'.format(round(H1,2)))
# Out:
#    waterfront      price
# 0           0  533137.61
# 1           1 1661876.02
# Houses with water view are 211.72% more expensive in average

# %% [markdown]
# H2: Houses built before 1955 are 50% cheaper

# %%
df = data.copy()
df['construction'] = df['yr_built'].apply(lambda x: 'Older than 1955' if x < 1955 else 'Newer then 1955')
df = df[['price', 'construction']].groupby('construction').mean().reset_index()
print(df)
H2 = abs((df.iloc[0,1]-df.iloc[1,1])/df.iloc[1,1])*100
print('Houses built before 1955 are {}% cheaper'.format(round(H2,2)))
# Out:
#       construction     price
# 0  Newer then 1955 542331.02
# 1  Older than 1955 540204.27
# Houses built before 1955 are 0.39% cheaper

# %% [markdown]
# H3: Houses without basement are 50% bigger then houses with basement

# %%
df = data.copy()
df['has_basement'] = df['sqft_basement'].apply(lambda x: 0 if x==0 else 1)
df = df[['sqft_lot', 'has_basement']].groupby('has_basement').mean().reset_index()
H3 = abs((df.iloc[0,1]-df.iloc[1,1])/df.iloc[0,1])*100
print('Houses without basement are {}% bigger'.format(round(H3,2)))
# Out:
# Houses without basement are 18.51% bigger

# %% [markdown]
# #H4: The YoY price growth is 10%.

# %%
df = data.copy()
df['year'] = data['date'].dt.year
df = df[['price', 'year']].groupby('year').mean().reset_index().sort_values(by='year')
df['YoY_%'] = abs((df['price'].diff(1))/df['price']*100)
H4 = df['YoY_%'].mean()
print('The average YoY price growth YoY is {}%'.format(round(H4,2)))
# Out:
# The average YoY price growth YoY is 0.2%

# %% [markdown]
# #H5: Houses with 3 bathrooms have MoM price growth of 15%

# %%
df = data[(data['bathrooms'] == 3)][['id', 'bathrooms', 'date', 'price']].copy()
df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m')
df = df[['price', 'date']].groupby('date').mean().reset_index()
df['MoM_%'] = df['price'].diff(1)/df['price']*100
H5 = df['MoM_%'].mean()
print('The average MoM price growth for 3 bathrooms houses is {}%'.format(round(H5,2)))
# Out:
# The average MoM price growth for 3 bathrooms houses is -0.33%

# %% [markdown]
# H6: Houses renovated are 15% more expesive

# %%
mean_renovated = data[(data['yr_renovated'] != 0)]['price'].mean()
mean_n_renovated = data[(data['yr_renovated'] == 0)]['price'].mean()
H6 = abs((mean_renovated - mean_n_renovated)/mean_n_renovated)*100
print('Houses renovated are {}% more expensive'.format(round(H6,2)))
# Out:
# Houses renovated are 43.32% more expensive

# %% [markdown]
# H7: Average price grows 10% as grade grows

# %%
df = data[['grade', 'price']].groupby('grade').mean().reset_index()
df['grade_%'] = df['price'].diff(1)/df['price']*100
H7 = df['grade_%'].mean()
print('The average price grows {}% as grade grows'.format(round(H7,2)))
# Out:
# The average price grows 24.5% as grade grows

# %% [markdown]
# H8: From houses recommended to be bought, the ones with condition 5 are 20% more profitable that those with condition 3

# %%
df1 = data[['id', 'condition']].copy()
df2 = pd.merge(summ_dataset, df1, on = 'id', how = 'inner')
mean_5 = df2[df2['condition'] == 5]['max_profit'].mean()
mean_3 = df2[df2['condition'] == 3]['max_profit'].mean()
H8 = ((mean_5 - mean_3)/mean_3)*100
print('Houses with condition 5 are {}% less profitable than houses with condition 3'.format(round(H8,2)))
# Out:
# Houses with condition 5 are -7.27% less profitable than houses with condition 3

# %% [markdown]
# H9: Most properties (+50%) became available during summer/spring.

# %%
df = season_df[['id', 'season']].copy()
df = df[['id', 'season']].groupby('season').count().reset_index()
H9 = (df[(df['season'] == 'spring') | (df['season'] == 'summer')]['id'].sum())/df['id'].sum()*100
print('{}% became available during summer or spring'.format(round(H9,2)))
# Out:
# 57.79% became available during summer or spring
